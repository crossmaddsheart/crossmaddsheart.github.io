# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams["font.family"] = "sans-serif"

import numpy as np
import collections
import pandas as pd

# %%
buildings = pd.read_csv("/Users/simpl/Documents/GradSchool/IS 445/week 3/building_inventory.csv")

# %%
buildings
# Out:
#                            Agency Name  \
# 0      Department of Natural Resources
# 1      Department of Natural Resources
# 2      Department of Natural Resources
# 3      Department of Natural Resources
# 4      Department of Natural Resources
# ...                                ...
# 8857      Department of Transportation
# 8858      Department of Transportation
# 8859      Department of Transportation
# 8860  Illinois Community College Board
# 8861    Department of Military Affairs
#
#                                           Location Name  \
# 0       Anderson Lake Conservation Area - Fulton County
# 1       Anderson Lake Conservation Area - Fulton County
# 2       Anderson Lake Conservation Area - Fulton County
# 3       Anderson Lake Conservation Area - Fulton County
# 4       Anderson Lake Conservation Area - Fulton County
# ...                                                 ...
# 8857  Belvidere Maintenance Storage Facility - Boone...
# ...

# %%
ag = buildings.groupby("Congress Dist")["Square Footage"].sum()
ag.plot.bar()

# %%
# This one was probably the easiest for me to complete. I didn't at first understand that it was shortening the square
# footage, so I got confused why the numbers weren't plotting right and ended up in a circle trying to plot the numbers
# correctly. I think otherwise this shows a pretty good visual and you can clearly see district 13 has the most sq ft
# I could not figure out how to add a y label, it kept throwing different errors about series, maybe because it's 
# aggrigated data.

# %%
ag = buildings.groupby("Congress Dist")["Square Footage"].mean()
ag.plot.bar(color='red')

# %%
# I had a similar problem with the graph making decisions. "How can the average be higher than the sum?" then I looked at 
# the y-axis and realized the scale was different. If comparing the 2, I would certainly keep them on the same scale or 
# have it clearly defined. Same problem as above, couldn't get a y labe to work. I also made this one a different color,
# to see if it would have similar properties to R studio. I think otherwise, you can see that district 7 has maybe fewer 
# larger buildings, but compared to the other one, district 13 has many smallish buildings, so the average is low,
# but the sum is high

# %%
ax = buildings.plot(x = "Year Acquired", y="Year Constructed", figsize=(20,6), rot=90, kind='scatter')
ax.set_xlim(1750, 2010)
ax.set_ylim(1750, 2010)
# Out:
# (1750.0, 2010.0)

# %%
# this one gave me the most trouble, because I don't think this really explains the relationship between the two. I feel as
# though a third measurement should be thrown in there to compare the two. I did try and find a way to get a line of best
# fit, but most required an additional package and didn't seem as useful. I feel maybe a doulbe bar chart would have 
# described the relationship better, but I could not get it to work. I think this visualization requires more background 
# info than the other bar charts due to not really seeing the relationship. You can see that some buildings were built
# before acquired and vice versa but it takes a bit of understanding to get there.
